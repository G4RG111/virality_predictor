# %% [markdown]
# # 03 — Model Training (Phase 3)
#
# Train XGBoost classifier on labeled virality outcome data.
# Requires: feature matrices from notebook 02 + outcome labels (viral=1, standard=0).
#
# Run this notebook after accumulating ≥50 labeled product outcomes.

# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import roc_auc_score, classification_report
import xgboost as xgb
import shap
import matplotlib.pyplot as plt

print('Phase 3 model training — requires labeled outcome data.')
print('Load your feature matrix CSV and outcome labels below.')

# %%
# Load feature matrix (generated from notebook 02 + external outcome labels)
# df = pd.read_csv('../data/processed/feature_matrix_labeled.csv')
# X = df.drop(['product_id', 'went_viral'], axis=1)
# y = df['went_viral']

# --- Placeholder until labeled data is available ---
print('TODO: Load labeled feature matrix once outcome data is available.')
print('Expected format: CSV with columns [product_id, hack_phrase_rate, obsession_phrase_rate, ..., went_viral]')

# %%
# Training template (run when data is available)
'''
model = xgb.XGBClassifier(
    n_estimators=200,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric='auc',
)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(model, X, y, cv=cv, scoring='roc_auc')
print(f'CV ROC-AUC: {scores.mean():.3f} ± {scores.std():.3f}')

model.fit(X, y)
model.save_model('../data/models/vibe_xgb_v1.json')
print('Model saved.')
'''
